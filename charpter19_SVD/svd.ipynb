# %% [markdown]
# #### SVD

# %%
import numpy as np

# %%
A = np.array([[0,1],[1,1],[1,0]])
A
# Out:
# array([[0, 1],
#        [1, 1],
#        [1, 0]])

# %%
u, s, vt = np.linalg.svd(A, full_matrices=True)
print(u.shape, s.shape, vt.shape)
# Out:
# (3, 3) (2,) (2, 2)

# %%
u
# Out:
# array([[-4.08248290e-01,  7.07106781e-01,  5.77350269e-01],
#        [-8.16496581e-01,  5.55111512e-17, -5.77350269e-01],
#        [-4.08248290e-01, -7.07106781e-01,  5.77350269e-01]])

# %%
s
# Out:
# array([1.73205081, 1.        ])

# %%
vt.T
# Out:
# array([[-0.70710678, -0.70710678],
#        [-0.70710678,  0.70710678]])

# %%
np.allclose(A, np.dot(u[:,:2]*s, vt))
# Out:
# True

# %%
np.dot(u[:,:2]*s, vt)
# Out:
# array([[ 1.11022302e-16,  1.00000000e+00],
#        [ 1.00000000e+00,  1.00000000e+00],
#        [ 1.00000000e+00, -3.33066907e-16]])

# %%
s_ = np.zeros((3,2))
for i in range(2):
    s_[i][i] = s[i]

s_
# Out:
# array([[1.73205081, 0.        ],
#        [0.        , 1.        ],
#        [0.        , 0.        ]])

# %%
np.dot(np.dot(u, s_), vt)
# Out:
# array([[ 1.11022302e-16,  1.00000000e+00],
#        [ 1.00000000e+00,  1.00000000e+00],
#        [ 1.00000000e+00, -3.33066907e-16]])

# %%
import numpy as np
import os
from PIL import Image
from tqdm import tqdm

# 定义恢复函数，由分解后的矩阵恢复到原矩阵
def restore(u, s, v, K): 
    m, n = len(u), len(v[0])
    a = np.zeros((m, n))
    for k in range(K):
        uk = u[:, k].reshape(m, 1)
        vk = v[k].reshape(1, n)
        a += s[k] * np.dot(uk, vk)   
    a = a.clip(0, 255)
    return np.rint(a).astype('uint8')

A = np.array(Image.open("./louwill.jpg", 'r'))
u_r, s_r, v_r = np.linalg.svd(A[:, :, 0])    
u_g, s_g, v_g = np.linalg.svd(A[:, :, 1])
u_b, s_b, v_b = np.linalg.svd(A[:, :, 2])

K = 50 
output_path = os.path.join('.', 'svd_pic')
os.makedirs(output_path, exist_ok=True)

for k in tqdm(range(1, K+1)):
    R = restore(u_r, s_r, v_r, k)
    G = restore(u_g, s_g, v_g, k)
    B = restore(u_b, s_b, v_b, k)
    I = np.stack((R, G, B), axis=2)   
    Image.fromarray(I).save(os.path.join(output_path, f'svd_{k}.jpg'))

# %%
A.shape
# Out:
# (959, 959, 3)
